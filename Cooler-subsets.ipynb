# %%
import pandas as pd
import numpy as np
import cooler
import matplotlib.pyplot as plt

# %%
chromosomes =['chr1','chr2','chr3','chr4','chr5','chr6','chr7','chr8','chr9','chr10','chr11','chr12','chr13','chr14','chr15','chr16','chr17','chr18','chr19','chr20','chr21','chr22','chrX','chrY']

# %%
c1 = cooler.Cooler('Calico/results/coolers_library/MC-HiC-DpnII-WI38-PDL25-TP2-R1__hg38.hg38.mapq_30.1000.mcool::/resolutions/1000000')
c2 = cooler.Cooler('Calico/results/coolers_library/MC-HiC-DpnII-WI38-PDL46-TP6-R1__hg38.hg38.mapq_30.1000.mcool::/resolutions/1000000')

# %%
A1 = c1.matrix().fetch('chr8:79250000-79500000','chr14')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0007)
A2 = c2.matrix().fetch('chr8:79250000-79500000','chr14')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0007)

# %%
A1 = c1.matrix().fetch('chr8:79250000-79500000','chr14')
img1 = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)
A2 = c2.matrix().fetch('chr8:79250000-79500000','chr14')
img2=plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)

# %%
A1 = c1.matrix().fetch('chr8:79000000-79750000','chr1')
img1 = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)
A2 = c2.matrix().fetch('chr8:79000000-79750000','chr1')
img2=plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)

# %%
x = np.array([[5, 2, 1], [4, 0, 6]], np.int32)
plt.matshow(x, cmap='YlOrRd',aspect='equal',extent=[0,1,0,2],vmin=1,vmax=5)

# %%
A1 = c1.matrix().fetch('chr2:1000000-2000000','chr1')
plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)
A2 = c2.matrix().fetch('chr2:1000000-2000000','chr1')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.0008)
A1.shape
# Out:
# (1, 249)

# %%
A1 = c1.matrix().fetch('chr8:71000000-79500000','chr8')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr8:71000000-79500000','chr8')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
A1 = c1.matrix().fetch('chr11:108500000-110750000','chr11')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr11:108500000-110750000','chr11')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
#similar
A1 = c1.matrix().fetch('chr1:242500000-244750000','chr1')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr1:242500000-244750000','chr1')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
#similar
A1 = c1.matrix().fetch('chr18:55500000-57750000','chr18')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr18:55500000-57750000','chr18')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
A1 = c1.matrix().fetch('chr1:156000000-156500000','chr1')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr1:156000000-156500000','chr1')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
A1 = c1.matrix().fetch('chr4:43500000-44500000','chr4')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr4:43500000-44500000','chr4')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
A1 = c1.matrix().fetch('chr11:100000000-109750000','chr11')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr11:100000000-109750000','chr11')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)

# %%
A1 = c1.matrix().fetch('chr13:107000000-109250000','chr13')
img = plt.matshow(A1, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
A2 = c2.matrix().fetch('chr13:107000000-109250000','chr13')
plt.matshow(A2, cmap='YlOrRd',extent=[0,100,0,4],aspect='equal',vmin=0,vmax=0.01)
