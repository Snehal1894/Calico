# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
files_hTERT =[
    'MC-HiC-DpnII-WI38-hTERT-TP2-R1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-hTERT-TP4-R1-1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-hTERT-TP4-R1-2.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-hTERT-TP5-R1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-hTERT-TP6-R1.cis.vecs.tsv'
]

files_PDL =[
    'MC-HiC-DpnII-WI38-PDL25-TP2-R1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-PDL33-TP4-R1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-PDL37-TP5-R1.cis.vecs.tsv',
    'MC-HiC-DpnII-WI38-PDL46-TP6-R1.cis.vecs.tsv'
]

names_hTERT = [
    'hTERT-TP2-R1',
    'hTERT-TP4-R1-1',
    'hTERT-TP4-R1-2',
    'hTERT-TP5-R1',
    'hTERT-TP6-R1'
]

names_PDL = [
    'PDL25-TP2-R1',
    'PDL33-TP4-R1',
    'PDL37-TP5-R1',
    'PDL46-TP6-R1'
]

# %%
fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(nrows=3, ncols=2)

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP2-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 0])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('hTERT-TP2-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP4-R1-1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 1])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('hTERT-TP4-R1-1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP5-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 0])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('hTERT-TP5-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP6-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 1])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('hTERT-TP6-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP4-R1-2.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[2, 0])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('hTERT-TP4-R1-2')
# Out:
# Text(0.5, 1.0, 'hTERT-TP4-R1-2')

# %%
fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(nrows=3, ncols=2)

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP2-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 0])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('hTERT-TP2-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP4-R1-1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 1])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('hTERT-TP4-R1-1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP5-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 0])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('hTERT-TP5-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP6-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 1])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('hTERT-TP6-R1')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-hTERT-TP4-R1-2.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[2, 0])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('hTERT-TP4-R1-2')
# Out:
# Text(0.5, 1.0, 'hTERT-TP4-R1-2')

# %%
fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(nrows=2, ncols=2)

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL25-TP2-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 0])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('PDL25')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL33-TP4-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 1])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('PDL33')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL37-TP5-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 0])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('PDL37')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL46-TP6-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 1])
f2=f1[['chrom','start','end','E1','E2']].dropna()
ax0.scatter(f2['E1'],f2['E2'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV2')
ax0.set_title('PDL46')
# Out:
# Text(0.5, 1.0, 'PDL46')

# %%
fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(nrows=2, ncols=2)

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL25-TP2-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 0])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('PDL25')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL33-TP4-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[0, 1])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('PDL33')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL37-TP5-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 0])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('PDL37')

f1 = pd.read_csv('MC-HiC-DpnII-WI38-PDL46-TP6-R1.cis.vecs.tsv', sep='\t', header=0)
ax0 = fig.add_subplot(gs[1, 1])
f2=f1[['chrom','start','end','E1','E3']].dropna()
ax0.scatter(f2['E1'],f2['E3'])
ax0.set_xlabel('EV1')
ax0.set_ylabel('EV3')
ax0.set_title('PDL46')
# Out:
# Text(0.5, 1.0, 'PDL46')
